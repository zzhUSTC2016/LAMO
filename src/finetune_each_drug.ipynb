# %%
import os
gpus = '1,0'
os.environ["CUDA_VISIBLE_DEVICES"] = gpus

from finetune_each_drug import finetune_each_drug

model_name = 'each_drug'

base_model = 'llama-2-7b'

finetune_each_drug(model_name, idx_start=10, idx_end=20, negative_ratio=-1, selected_drugs=None, base_model=base_model)
# Out:
# ------ Single drug evaluation: Merging lora weights and saving hf model ------
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# INFO 12-02 14:48:20 llm_engine.py:72] Initializing an LLM engine with config: model='../Models/each_drug_10_20/checkpoint-1088', tokenizer='../Models/each_drug_10_20/checkpoint-1088', tokenizer_mode=auto, revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=2048, download_dir=None, load_format=auto, tensor_parallel_size=1, quantization=None, seed=0)
# INFO 12-02 14:48:41 llm_engine.py:205] # GPU blocks: 6453, # CPU blocks: 512
# Processed prompts: 100%|██████████| 2421/2421 [01:40<00:00, 24.16it/s]
# 2023-12-02 14:50:27,446 - INFO - med:Lorazepam               , recall:0.6697  precision:0.5795  f1:0.6214  jaccard:0.4507  drug_pred:1144/2421, drug_gt:990
# 2023-12-02 14:50:27,446 - INFO - med:Lorazepam               , recall:0.6697  precision:0.5795  f1:0.6214  jaccard:0.4507  drug_pred:1144/2421, drug_gt:990
# ...

# %%
data
# Out:
#       SUBJECT_ID  HADM_ID                                           diagnose  \
# 0             17   161087  ['Pericardial disease NOS', 'Pleural effusion ...
# 1             17   194023  ['Secundum atrial sept def', 'Iatrogenc hypotn...
# 2             21   109451  ['Subendo infarct, initial', 'Cardiogenic shoc...
# 3             21   111970  ['Septicemia NEC', 'Septic shock', 'Hyp kid NO...
# 4             23   124321  ['Ben neo cerebr meninges', 'Cerebral edema', ...
# ...          ...      ...                                                ...
# 9955       31994   130132  ['Subendo infarct, initial', 'End stage renal ...
# 9956       31994   177546  ['Systolic hrt failure NOS', 'Cardiogenic shoc...
# 9957       32005   118675  ['Blood in stool', 'Ac posthemorrhag anemia', ...
# 9958       32005   159699  ['Gastrointest hemorr NOS', 'Acute kidney fail...
# 9959       32005   190385  ['Acute kidney failure NOS', 'Chr systolic hrt...
#
# ...

# %%
import sys
sys.path.append('../')
import utils
data, med_names, _ = utils.load_data()

# 以idx->med_name的方式输出
idx2med_names = {}
for idx, med_name in enumerate(med_names):
    idx2med_names[idx] = med_name
idx2med_names
# Out:
# {0: 'Acetaminophen',
#  1: 'Potassium chloride',
#  2: 'Pantoprazole',
#  3: 'Metoprolol',
#  4: 'Magnesium sulfate',
#  5: 'Furosemide',
#  6: 'Vancomycin',
#  7: 'Salbutamol',
#  8: 'Oxycodone',
#  9: 'Bisacodyl',
#  10: 'Lorazepam',
#  11: 'Magnesium',
#  12: 'Ipratropium',
#  13: 'Acetylsalicylic acid',
#  14: 'Morphine',
#  15: 'Ondansetron',
#  16: 'Fentanyl',
#  17: 'Calcium gluconate',
#  18: 'D-glucose',
#  19: 'Propofol',
#  20: 'Lansoprazole',
#  21: 'Hydromorphone',
#  22: 'Levofloxacin',
#  23: 'Atorvastatin',
#  24: 'Metronidazole',
#  25: 'Midazolam',
#  26: 'Lisinopril',
#  27: 'Warfarin',
#  28: 'Lidocaine',
#  29: 'Famotidine',
#  30: 'Hydralazine',
#  31: 'Chlorhexidine',
#  32: 'Phenylephrine',
#  33: 'Metoclopramide',
#  34: 'Ciprofloxacin',
#  35: 'Spironolactone',
#  36: 'Nitroglycerin',
#  37: 'Prednisone',
#  38: 'Sodium bicarbonate',
#  39: 'Tazobactam',
#  40: 'Diphenhydramine',
#  41: 'Omeprazole',
#  42: 'Lactulose',
#  43: 'Clopidogrel',
# ...
